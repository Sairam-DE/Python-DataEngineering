# %% [markdown]
# <a href="https://colab.research.google.com/github/Sairam-DE/Python-DataEngineering/blob/main/pandas_tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
pandas is a software library written for the python programming language for data
manipulation

works for tabular data
pandas capable of offering in-memory 2d table object called dataframe
pandas data structures are the series and the data frame
series = single column of data
dataframe = sheet with rows and columns

three main data structures in pandas
series-1d
dataframe - 2d (main focus)
panel - 3d
"""

# %%
#installation

# !pip install pandas

# %%
import pandas

# %%
print(pandas.__version__)
# Out:
# 1.5.3

# %%
"""
a data set is a collection of data
data is information recorded systematically and stated within its context

"""

# %% [markdown]
# # CREATING A DATA FRAME

# %%
import pandas as pd
d=pd.read_csv('/content/sample_data/california_housing_test.csv')
df=pd.DataFrame(d)

# %%
#print(df) -- see the variation by uncommenting
df
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %%
#same goes with excel also
'''
read_excel("file_location")
'''

# %%
#CREATING DATA FRAME USING DICTIONARY
import pandas as pd

# Sample dictionary data
dict = {'Name': ['Alice', 'Bob', 'Charlie', 'David'],
        'Age': [25, 30, 35, 40],
        'City': ['New York', 'Los Angeles', 'Chicago', 'Houston']}

# %%
dict
# Out:
# {'Name': ['Alice', 'Bob', 'Charlie', 'David'],
#  'Age': [25, 30, 35, 40],
#  'City': ['New York', 'Los Angeles', 'Chicago', 'Houston']}

# %%
df = pd.DataFrame(dict)
print(df)
# Out:
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago
# 3    David   40      Houston

# %%
#CREATING DATA FRAME USING tuple

import pandas as pd

# Sample tuple data
data = [('Alice', 25, 'New York'),
        ('Bob', 30, 'Los Angeles'),
        ('Charlie', 35, 'Chicago'),
        ('David', 40, 'Houston')]

# Creating DataFrame
df = pd.DataFrame(data, columns=['Name', 'Age', 'City'])

print(df)
# Out:
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago
# 3    David   40      Houston

# %% [markdown]
# INDEXING SLICING

# %%
#used this again for doing operations on this dataset
import pandas as pd
d=pd.read_csv('/content/sample_data/california_housing_test.csv')
df=pd.DataFrame(d)

# %%
#data_frame.head(number_of_rows)

df.head() #works with out explicitly
#by using head we get first records
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
#need something particularly
df.head(2)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0

# %%
#data_frame.tail(number_of_rows)

#by using tail we last records of data set
df.tail()
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# 2995      1258.0       607.0         1.1790            225000.0
# 2996      3496.0      1036.0         3.3906            237200.0
# 2997       693.0       220.0         2.2895             62000.0
# 2998        46.0        14.0         3.2708            162500.0
# 2999       753.0       260.0         8.5608            500001.0

# %%
df.tail(1)
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# 2999       753.0       260.0         8.5608            500001.0

# %%
df.describe() #we get all aggregations by using describe
# Out:
#          longitude    latitude  housing_median_age   total_rooms  \
# count  3000.000000  3000.00000         3000.000000   3000.000000
# mean   -119.589200    35.63539           28.845333   2599.578667
# std       1.994936     2.12967           12.555396   2155.593332
# min    -124.180000    32.56000            1.000000      6.000000
# 25%    -121.810000    33.93000           18.000000   1401.000000
# 50%    -118.485000    34.27000           29.000000   2106.000000
# 75%    -118.020000    37.69000           37.000000   3129.000000
# max    -114.490000    41.92000           52.000000  30450.000000
#
#        total_bedrooms    population  households  median_income  \
# count     3000.000000   3000.000000  3000.00000    3000.000000
# mean       529.950667   1402.798667   489.91200       3.807272
# std        415.654368   1030.543012   365.42271       1.854512
# min          2.000000      5.000000     2.00000       0.499900
# ...

# %%
df.shape #gives rows and columns
# Out:
# (3000, 9)

# %%
#data_frame[start:stop:step]
df[0:800:2]
#starts at 0 index
#ends at 800 index
#with difference of 2
# Out:
#      longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0      -122.05     37.37                27.0       3885.0           661.0
# 2      -117.81     33.78                27.0       3589.0           507.0
# 4      -119.67     36.33                19.0       1241.0           244.0
# 6      -121.43     38.63                43.0       1009.0           225.0
# 8      -122.84     38.40                15.0       3080.0           617.0
# ..         ...       ...                 ...          ...             ...
# 790    -123.74     40.66                25.0       2395.0           431.0
# 792    -118.91     34.22                15.0       5644.0           757.0
# 794    -121.80     38.01                46.0       2273.0           495.0
# 796    -122.14     37.67                34.0       3036.0           533.0
# 798    -122.10     37.65                31.0       1797.0           327.0
#
#      population  households  median_income  median_house_value
# ...

# %%
df["longitude"] #accessing single column
# Out:
# 0      -122.05
# 1      -118.30
# 2      -117.81
# 3      -118.36
# 4      -119.67
#          ...
# 2995   -119.86
# 2996   -118.14
# 2997   -119.70
# 2998   -117.12
# 2999   -119.63
# Name: longitude, Length: 3000, dtype: float64

# %%
df[["longitude", "latitude",	"housing_median_age"]] #accessing multiple colums
# Out:
#       longitude  latitude  housing_median_age
# 0       -122.05     37.37                27.0
# 1       -118.30     34.26                43.0
# 2       -117.81     33.78                27.0
# 3       -118.36     33.82                28.0
# 4       -119.67     36.33                19.0
# ...         ...       ...                 ...
# 2995    -119.86     34.42                23.0
# 2996    -118.14     34.06                27.0
# 2997    -119.70     36.30                10.0
# 2998    -117.12     34.10                40.0
# 2999    -119.63     34.42                42.0
#
# [3000 rows x 3 columns]

# %%
#we can use start stop and step also here(slicing)

df[["longitude", "latitude",	"housing_median_age"]] [0:500:3]
# Out:
#      longitude  latitude  housing_median_age
# 0      -122.05     37.37                27.0
# 3      -118.36     33.82                28.0
# 6      -121.43     38.63                43.0
# 9      -118.02     34.08                31.0
# 12     -121.93     37.25                36.0
# ..         ...       ...                 ...
# 486    -121.50     36.81                20.0
# 489    -118.42     34.23                34.0
# 492    -119.74     34.35                34.0
# 495    -122.29     37.82                 2.0
# 498    -122.44     37.76                52.0
#
# [167 rows x 3 columns]

# %%
#we can get individual records like this

for x in df.iterrows():
    print(x)
# Out:
# Streaming output truncated to the last 5000 lines.
# (2500, longitude               -118.34
# latitude                  34.09
# housing_median_age        14.00
# total_rooms             3032.00
# total_bedrooms           999.00
# population              1691.00
# households               841.00
# median_income              2.20
# median_house_value    210000.00
# Name: 2500, dtype: float64)
# (2501, longitude               -117.6100
# latitude                  34.3400
# housing_median_age        18.0000
# total_rooms             5210.0000
# total_bedrooms           912.0000
# population              1301.0000
# households               464.0000
# median_income              4.8623
# median_house_value    176900.0000
# Name: 2501, dtype: float64)
# (2502, longitude              -118.23
# latitude                 33.76
# housing_median_age       21.00
# total_rooms              49.00
# total_bedrooms           14.00
# population               29.00
# households               16.00
# ...

# %%
#loc
#stop index included
#we acess columns with column name

# %%
#loc (stop index included)
#data_frame.loc[row_number]
df.loc[20]
# Out:
# longitude               -122.1500
# latitude                  37.7500
# housing_median_age        40.0000
# total_rooms             1445.0000
# total_bedrooms           256.0000
# population               849.0000
# households               255.0000
# median_income              3.8913
# median_house_value    126300.0000
# Name: 20, dtype: float64

# %%
#data_frame.loc[row_number, [column_name,...]]

df.loc[78,["latitude"]]
# Out:
# latitude    34.17
# Name: 78, dtype: float64

# %%
df.loc[69,["latitude", "total_rooms",	"total_bedrooms",]]
# Out:
# latitude            33.86
# total_rooms       1691.00
# total_bedrooms     367.00
# Name: 69, dtype: float64

# %%
df.loc[8:69,["latitude", "total_rooms",	"total_bedrooms",]]
#starts from 8 and includes 69 also in normal case 69 is excluded but here it is
#included
# Out:
#     latitude  total_rooms  total_bedrooms
# 8      38.40       3080.0           617.0
# 9      34.08       2402.0           632.0
# 10     33.98        972.0           249.0
# 11     35.85        736.0           166.0
# 12     37.25       1089.0           182.0
# ..       ...          ...             ...
# 65     32.73       3966.0           768.0
# 66     37.69       6473.0          1212.0
# 67     33.92       2290.0           319.0
# 68     34.08       3830.0           750.0
# 69     33.86       1691.0           367.0
#
# [62 rows x 3 columns]

# %%
#range
df.loc[0:45, "longitude":"latitude"]
# Out:
#     longitude  latitude
# 0     -122.05     37.37
# 1     -118.30     34.26
# 2     -117.81     33.78
# 3     -118.36     33.82
# 4     -119.67     36.33
# 5     -119.56     36.51
# 6     -121.43     38.63
# 7     -120.65     35.48
# 8     -122.84     38.40
# 9     -118.02     34.08
# 10    -118.24     33.98
# 11    -119.12     35.85
# 12    -121.93     37.25
# 13    -117.03     32.97
# 14    -117.97     33.73
# 15    -117.99     33.81
# 16    -120.81     37.53
# 17    -121.20     38.69
# 18    -118.88     34.21
# 19    -122.59     38.01
# 20    -122.15     37.75
# 21    -121.37     38.68
# 22    -118.16     34.07
# 23    -122.20     37.79
# 24    -117.28     33.28
# 25    -118.03     34.16
# 26    -122.42     37.76
# 27    -118.39     33.99
# 28    -118.45     34.07
# 29    -118.48     34.01
# 30    -119.35     36.33
# 31    -118.30     33.91
# 32    -121.13     39.31
# 33    -118.08     34.55
# 34    -118.32     33.94
# 35    -118.11     34.00
# 36    -122.53     37.97
# ...

# %%
#iloc
#stop index excluded
#column names are accessed with numbers

# %%
#now operations with iloc
#data_frame.iloc[row_number, column_number]
df.iloc[0:4]
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0

# %%
#data_frame.iloc[row_number,column_number]

df.iloc[2,4] #here we are accesing second row fourth column
# Out:
# 507.0

# %%
#data_frame.iloc[row_start:row_stop, col_start:col_stop]
df.iloc[0:5, 4:8]
# Out:
#    total_bedrooms  population  households  median_income
# 0           661.0      1537.0       606.0         6.6085
# 1           310.0       809.0       277.0         3.5990
# 2           507.0      1484.0       495.0         5.7934
# 3            15.0        49.0        11.0         6.1359
# 4           244.0       850.0       237.0         2.9375

# %%
#data_frame.iloc[start:stop, "column_number"]
df.iloc[7:68, 2]
# Out:
# 7     19.0
# 8     15.0
# 9     31.0
# 10    45.0
# 11    37.0
#       ...
# 63    31.0
# 64    26.0
# 65    38.0
# 66    19.0
# 67    12.0
# Name: housing_median_age, Length: 61, dtype: float64

# %%
#data_frame.iloc[[row_1, row_2, ....]]
df.iloc[[1,2,3]] #instead of range
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
#
#    population  households  median_income  median_house_value
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0

# %%
df.iloc[[3, 89, 2560]]
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 3       -118.36     33.82                28.0         67.0            15.0
# 89      -122.40     37.62                44.0       1619.0           362.0
# 2560    -122.32     38.32                22.0       2483.0           528.0
#
#       population  households  median_income  median_house_value
# 3           49.0        11.0         6.1359            330000.0
# 89        1064.0       335.0         4.0238            224200.0
# 2560      1478.0       492.0         4.0878            164400.0

# %%
#data_frame.iloc[:, [col_1, col_2,...]]
df.iloc[:,[1,2,3]]
# Out:
#       latitude  housing_median_age  total_rooms
# 0        37.37                27.0       3885.0
# 1        34.26                43.0       1510.0
# 2        33.78                27.0       3589.0
# 3        33.82                28.0         67.0
# 4        36.33                19.0       1241.0
# ...        ...                 ...          ...
# 2995     34.42                23.0       1450.0
# 2996     34.06                27.0       5257.0
# 2997     36.30                10.0        956.0
# 2998     34.10                40.0         96.0
# 2999     34.42                42.0       1765.0
#
# [3000 rows x 3 columns]

# %%
df.iloc[:,[3,6,7]]
# Out:
#       total_rooms  households  median_income
# 0          3885.0       606.0         6.6085
# 1          1510.0       277.0         3.5990
# 2          3589.0       495.0         5.7934
# 3            67.0        11.0         6.1359
# 4          1241.0       237.0         2.9375
# ...           ...         ...            ...
# 2995       1450.0       607.0         1.1790
# 2996       5257.0      1036.0         3.3906
# 2997        956.0       220.0         2.2895
# 2998         96.0        14.0         3.2708
# 2999       1765.0       260.0         8.5608
#
# [3000 rows x 3 columns]

# %%
#data_frame.iloc[[start:stop], [col_1, col_2,...]]
df.iloc[[2,80],[1,3,6]]
# Out:
#     latitude  total_rooms  households
# 2      33.78       3589.0       495.0
# 80     37.40        860.0       147.0
# 5      36.51       1018.0       204.0

# %%
df.iloc[[2,78,90],[1,3,6]]
# Out:
#     latitude  total_rooms  households
# 2      33.78       3589.0       495.0
# 78     34.17       6217.0       834.0
# 90     34.15       1125.0       321.0

# %%
#sorting dataframe
#data_frame.sort_values("column_name")

df.sort_values("latitude")
#by default it chooses ascending
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1208    -117.09     32.56                 8.0        864.0           156.0
# 2371    -117.08     32.57                18.0       2203.0           544.0
# 1617    -117.12     32.57                35.0       1450.0           256.0
# 1045    -117.11     32.57                32.0       2723.0           586.0
# 274     -117.05     32.58                23.0       1918.0           339.0
# ...         ...       ...                 ...          ...             ...
# 2018    -122.32     41.31                45.0       1393.0           294.0
# 2778    -123.92     41.54                22.0       2920.0           636.0
# 2951    -122.64     41.63                19.0       2722.0           479.0
# 1422    -124.17     41.80                16.0       2739.0           480.0
# 910     -124.16     41.92                19.0       1668.0           324.0
#
#       population  households  median_income  median_house_value
# ...

# %%
df.sort_values("latitude", ascending=False)
#now we can do descending by passing false to ascending
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 910     -124.16     41.92                19.0       1668.0           324.0
# 1422    -124.17     41.80                16.0       2739.0           480.0
# 2951    -122.64     41.63                19.0       2722.0           479.0
# 2778    -123.92     41.54                22.0       2920.0           636.0
# 2018    -122.32     41.31                45.0       1393.0           294.0
# ...         ...       ...                 ...          ...             ...
# 2649    -117.13     32.58                27.0       2511.0           615.0
# 1045    -117.11     32.57                32.0       2723.0           586.0
# 1617    -117.12     32.57                35.0       1450.0           256.0
# 2371    -117.08     32.57                18.0       2203.0           544.0
# 1208    -117.09     32.56                 8.0        864.0           156.0
#
#       population  households  median_income  median_house_value
# ...

# %%
#data_frame.sort_values(["column_1", "column_2"])
df.sort_values(["latitude", "longitude"])
#here the ascending order done by the column_1 what we given w.r.to that
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1208    -117.09     32.56                 8.0        864.0           156.0
# 1617    -117.12     32.57                35.0       1450.0           256.0
# 1045    -117.11     32.57                32.0       2723.0           586.0
# 2371    -117.08     32.57                18.0       2203.0           544.0
# 2649    -117.13     32.58                27.0       2511.0           615.0
# ...         ...       ...                 ...          ...             ...
# 2018    -122.32     41.31                45.0       1393.0           294.0
# 2778    -123.92     41.54                22.0       2920.0           636.0
# 2951    -122.64     41.63                19.0       2722.0           479.0
# 1422    -124.17     41.80                16.0       2739.0           480.0
# 910     -124.16     41.92                19.0       1668.0           324.0
#
#       population  households  median_income  median_house_value
# ...

# %%
df.sort_values(["longitude", "latitude"])
#here sorting goes with longitude
#the first given column plays a key role
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1876    -124.18     40.79                40.0       1398.0           311.0
# 1422    -124.17     41.80                16.0       2739.0           480.0
# 111     -124.16     40.77                35.0       2141.0           438.0
# 2577    -124.16     40.79                46.0       3042.0           597.0
# 1118    -124.16     40.80                52.0       2167.0           480.0
# ...         ...       ...                 ...          ...             ...
# 244     -114.98     33.07                18.0       1183.0           363.0
# 2640    -114.62     33.62                26.0         18.0             3.0
# 1145    -114.61     33.62                16.0       1187.0           261.0
# 1595    -114.55     32.80                19.0       2570.0           820.0
# 2055    -114.49     33.97                17.0       2809.0           635.0
#
#       population  households  median_income  median_house_value
# ...

# %%
df.sort_values(["longitude", "latitude"], ascending=[0,1])
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2055    -114.49     33.97                17.0       2809.0           635.0
# 1595    -114.55     32.80                19.0       2570.0           820.0
# 1145    -114.61     33.62                16.0       1187.0           261.0
# 2640    -114.62     33.62                26.0         18.0             3.0
# 244     -114.98     33.07                18.0       1183.0           363.0
# ...         ...       ...                 ...          ...             ...
# 2577    -124.16     40.79                46.0       3042.0           597.0
# 1118    -124.16     40.80                52.0       2167.0           480.0
# 910     -124.16     41.92                19.0       1668.0           324.0
# 1422    -124.17     41.80                16.0       2739.0           480.0
# 1876    -124.18     40.79                40.0       1398.0           311.0
#
#       population  households  median_income  median_house_value
# ...

# %% [markdown]
# #manipulating a data frame
# #add or remove

# %%
#Data_Frame['new_col_name']=default_value

df["total"]=0

# %%
df
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
# ...

# %%
#there you can see total is added as a new column

# %%
#now with expression
#Data_Frame['new_col_name']=Expression/Condition

df["total"]=df["longitude"]+df["latitude"]

# %%
df
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
# ...

# %%
#now you can see df got values of addition of longitude,latitude
#these changes only we can see in the data set not in the original file

# %%
df["gender"]="m/f"

# %%
df
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
# ...

# %% [markdown]
# #REMOVING COLUMN

# %%
#Data_frame.drop(columns="column_name")
df.drop(columns="gender")
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
# ...

# %%
df.drop(columns="gender", inplace=True)
#permanently going to delete in dataframe by using inplace=True

# %%
df
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
# ...

# %% [markdown]
# REMOVING DUPLICATES

# %%
#Knowing Duplicates
#Dat_frame.duplicated() - Boolean Result
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2995    False
# 2996    False
# 2997    False
# 2998    False
# 2999    False
# Length: 3000, dtype: bool

# %%
df.drop_duplicates()
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
# ...

# %% [markdown]
# Handling Missing Data

# %%
#Data_frame.fillna(default_value)
#FILL WITH DEFAULT VALUES
df.fillna(80)
#we are going to fill every missing value with 80
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
# ...

# %%
df["latitude"].fillna(90)
#we are going fill every missing value with 90
#in latitude
#we can also do all the operation here like start stop and step
# Out:
# 0       37.37
# 1       34.26
# 2       33.78
# 3       33.82
# 4       36.33
#         ...
# 2995    34.42
# 2996    34.06
# 2997    36.30
# 2998    34.10
# 2999    34.42
# Name: latitude, Length: 3000, dtype: float64

# %%
df
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
# ...

# %%
#Data_frame.dropna()
#REMOVE MISSING DATA
df.dropna()
#will remove all the missing values
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
# ...

# %%
#permanent removal
df.dropna(inplace=True)

# %%
df
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
# ...

# %% [markdown]
# DATA FILTERING AND CONDITIONAL CHANGES

# %%
#Data_frame.loc[simple_condition]

#Data_frame.loc[compund_condition]

#Data_frame.loc[simple_condition.str.contains(str)]

#Data_frame.loc[simple_condition.str.startswith(str)]

#Data_frame.loc[simple_condition.str.endswith(str)]

#Simple Condition

#Data_frame["Col_name"] > / < / == value

# %%
#Data_frame.loc[simple_condition]

df.loc[df["latitude"]<85]
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
# ...

# %%
#Data_frame[compound_condition]
df.loc[(df["latitude"]<35) & (df["latitude"]>40)]
# Out:
# Empty DataFrame
# Columns: [longitude, latitude, housing_median_age, total_rooms, total_bedrooms, population, households, median_income, median_house_value, total]
# Index: []

# %%
#String condition
#df.loc[df[" "]].str.contains(" ")

# %%
#df.loc[df[" "]].str.startswith(" ")

# %%
df["percentage"]=(df["total"]/200)*100
#in this way we can calculate percentage also

# %% [markdown]
# EXPORT DATA FRAME
#       TO
#       EXCEL,CSV,&TEXT FILE

# %%
#Data_frame.to_excel(PATH)

#Data_frame.to_excel(PATH,index=False)--index will be deleted

#Data_frame.to_csv(PATH)

#Data_frame.to_csv(PATH,index=False)
